# %% [markdown]
# # TODOs
#
# * write linguistic rules to catch research questions until 100+ samples
# * tryout DBSCAN on that

# %%
import json

# %%
with open('sample.jsonl', 'r') as json_file:
    json_list = list(json_file)

# %%
json_list[3]
# Out:
# '{"paper_id": "94551546", "_pdf_hash": "9bf1cb19041b8ddfca7aeccc9d2f7689c8aa1c7e", "abstract": [{"section": "Abstract", "text": "Ethanolamine (EA) or ethylenediamine (ED)-functionalized poly(glycidyl methacrylate) (PGMA), namely PGEA or PGED, has recently been used as effective gene carriers because of their low cytotoxicity and high transfection efficiency. In this study, a series of PGMA-based supramolecular polycations (PGED-Gd@PGEAs) with magnetic resonance imaging (MRI) functions were readily constructed by assembling multiple adamantine-headed star PGEA (Ad-PGEA) units with a versatile PGED-CD-Gd backbone, which possessed numerous flanking \\u03b2-cyclodextrin species and Gd 3+ ions. The properties of different PGED-Gd@PGEA vectors were systematically characterized, including the plasmid DNA condensation ability, cytotoxicity, gene transfection efficiency, cellular uptake and MRI function. Such supramolecular gene vectors had lower toxicity than \'gold standard\' polyethylenimi
# ...

# %%
entries = [json.loads(s) for s in json_list ]

# %%
from IPython.display import JSON
JSON({"a":5, "b":3}, expanded=True)

# %%
entries[0]
# Out:
# {'paper_id': '77499681',
#  '_pdf_hash': '11f281316fe4638843a83cf559ce4f60aade00f8',
#  'abstract': [{'section': 'Abstract',
# ...

# %%
from pydash import get
#['abstract', 0, , 'c', 1]
get(entries[1], "abstract[0].text")

# %%
[e["abstract"] for e in entries][0][0]["text"]
# Out:
# 'The purpose of this study is to evaluate the effects of teriparatide administration on fracture healing after intramedullary nailing in atypical femoral fractures. Materials and Methods: We retrospectively reviewed 26 patients (26 cases) with atypical femoral fracture who were treated using intramedullary nailing between January 2009 and December 2013. Teriparatide was not administered to 15 patients (non-injection group) and was administered to 11 patients after surgery (injection group). Clinical results were assessed using the Nakajima score and the visual analogue scale (VAS). Radiographic results were compared for the time of callus formation, callus bridge formation, and bone union between the groups. Results: Time to recover walking ability and to decrease pain in the surgery region (VAS≤2) were significantly shorter in the injection group than in the non-injection group. The time of callus formation, callus bridge formation, and bone union was significantly shorter in the in
# ...

# %%
entries[0].get("abstract")[0].get("text"), getattr(entries[0], 'abstract', [{"text":""}])[0]["text"]
# Out:
# ('The purpose of this study is to evaluate the effects of teriparatide administration on fracture healing after intramedullary nailing in atypical femoral fractures. Materials and Methods: We retrospectively reviewed 26 patients (26 cases) with atypical femoral fracture who were treated using intramedullary nailing between January 2009 and December 2013. Teriparatide was not administered to 15 patients (non-injection group) and was administered to 11 patients after surgery (injection group). Clinical results were assessed using the Nakajima score and the visual analogue scale (VAS). Radiographic results were compared for the time of callus formation, callus bridge formation, and bone union between the groups. Results: Time to recover walking ability and to decrease pain in the surgery region (VAS≤2) were significantly shorter in the injection group than in the non-injection group. The time of callus formation, callus bridge formation, and bone union was significantly shorter in the i
# ...

# %%
text_entries = [e for e in entries if e["abstract"]]

len(entries), len(text_entries) #getattr(e, 'abstract', [{"text":""}]) [0]["text"]])
# Out:
# (203, 78)

# %%
import csv

with open('samples.csv', 'w') as output:
    writer = csv.writer(output)
    writer.writerow(["Abstract"])
    for e in text_entries:
        text= e["abstract"][0]["text"]
        writer.writerow([text])

# %%
text_entries[4]
# Out:
# {'paper_id': '18980463',
#  '_pdf_hash': 'ac3a8d3545ca7c673ddbfbf2f503e40f6317eb6f',
#  'abstract': [{'section': 'Abstract',
# ...

# %%
"".split(".")[0]
# Out:
# ''

# %%
extractors = [
    lambda t: t.split('.')[0], #just first sentence
]

# %%
cue_phrases = [
    "The purpose of this study",
    "In this study",
    "This study",
    "We show here that",

    "In this paper",

    "It is shown that",

    "In this work",


    "We describe",

    "This study analyzed",

    "In the present work",
    "The aim with this",

    "The authors conducted",
    "We hypothesized that",
    "We prove",
    
    "We revisit",
    "We propose",

    "This paper",
    "Objective:",
    "Our goal was",

   # "was perfomed",

    "To investigate",
    "We reanalyzed", 
    "We confirmed",
    "It is also shown",
    "We successfully detect",

    "We find",
    "We investigate",
    "In this research"
]

# %%
def find_sentence_in_abstract(paragraph, cue_phrases=cue_phrases):
    """checks paragraph for key sentences. Returns first matching hit"""
    p_sents = paragraph.split(".")
    combinations = itertools.product(p_sents, cue_phrases)
    hit = ""
    for c in combinations:
        if c[1] in c[0]:
       # if c[0].startswith(c[1]): #easier to work with later assuming beginning of sentence
            hit = c[0]
            print(hit[:44])
            break
    return hit

# %%
#extract all sentences containing cue_phrase

coll = [{"text": e["abstract"][0]["text"], "paper_id": e["paper_id"]} for e in text_entries]

# %%
[c.update({"phrase": find_sentence_in_abstract(c["text"]) }) for c in coll]
5
# Out:
# The purpose of this study is to evaluate the
#  In this study, a series of PGMA-based supra
#  This paper exhibits a report on the achieve
#  We show here that the larval eye is compose
#  This study was designed to identify risk fa
#  In this paper we consider two types of loca
# In this paper I discuss some constraints and
# Abstract-This paper gives a comprehensive st
# It is shown that the local solution of parab
#  In this work, a fusion protein with DDD was
# We describe cloned segments of rDNA that con
#  In this paper I review such a result by dis
#  This study analyzed the spatio-temporal pat
#  In this work we study the production of tri
#  In the present work, we constructed a high-
#  The aim with this study was to describe the
#  Methods: The authors conducted a literature
#  We hypothesized that lipid disorders (LDs),
#  We prove existence and uniform bounds for c
#  This paper proposes a method of high accura
#  In this study, salivary samples from indivi
# ...

# %%
coll
# Out:
# [{'text': 'The purpose of this study is to evaluate the effects of teriparatide administration on fracture healing after intramedullary nailing in atypical femoral fractures. Materials and Methods: We retrospectively reviewed 26 patients (26 cases) with atypical femoral fracture who were treated using intramedullary nailing between January 2009 and December 2013. Teriparatide was not administered to 15 patients (non-injection group) and was administered to 11 patients after surgery (injection group). Clinical results were assessed using the Nakajima score and the visual analogue scale (VAS). Radiographic results were compared for the time of callus formation, callus bridge formation, and bone union between the groups. Results: Time to recover walking ability and to decrease pain in the surgery region (VAS≤2) were significantly shorter in the injection group than in the non-injection group. The time of callus formation, callus bridge formation, and bone union was significantly shorter
# ...

# %%
#now plug the general part and extract the essential idea
from spacy import displacy

docs = [nlp(c["phrase"]) for c in coll]

# %%
[displacy.render(doc, style="dep") for doc in docs]
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c415ecd791b34365acd346a9e30f046f-0" class="displacy" width="4075" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">purpose</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
# ...

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp("Autonomous cars shift insurance liability toward manufacturers")
for chunk in doc.noun_chunks:
    print(chunk.text, chunk.root.text, chunk.root.dep_,
            chunk.root.head.text)
# Out:
# Autonomous cars cars nsubj shift
# insurance liability liability dobj shift
# manufacturers manufacturers pobj toward
